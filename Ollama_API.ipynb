# %% [markdown]
# <a href="https://colab.research.google.com/github/Nguyenchau4519/Core_MVC/blob/master/Ollama_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt update
# !sudo apt install -y pciutils
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,683 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:12 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,958 kB]
# ...

# %%
import time
import threading
import subprocess

def ollama_service_start():
  subprocess.Popen(['ollama', 'serve'])

thread = threading.Thread(target=ollama_service_start)
thread.start()
time.sleep(5)

# %%
# !ollama list
# Out:
# NAME        ID              SIZE      MODIFIED
# qwen3:8b    e4b5fd7f8af0    5.2 GB    About a minute ago

# %%
# !ollama pull qwen3:8b

# %%
from google.colab import userdata
auth_token = userdata.get('NGROK_AUTH_TOKEN')

# %%
# !wget -q https://bin.equinox.io/c/bNyj1mQVY4c/ngrok-v3-stable-linux-amd64.tgz
# !tar -xvf ngrok-v3-stable-linux-amd64.tgz
# !./ngrok authtoken {auth_token}
# Out:
# ngrok
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !ngrok config add-authtoken 2xLIvb1I0qyGxQvA2BosTFoAEiF_pzyzw1sBrmLFSq5quVDk
# Out:
# /bin/bash: line 1: ngrok: command not found

# %%
import os
os.environ['OLLAMA_HOST'] = 'localhost'

# %%
from google.colab import userdata
auth_token = userdata.get('NGROK_AUTH_TOKEN')
# !./ngrok authtoken {auth_token}
# !ollama serve & ./ngrok http 11434 --host-header="localhost:11434" --domain="unbiased-blessed-guinea.ngrok-free.app" --log stdout & sleep 5s && ollama run qwen3:8b
